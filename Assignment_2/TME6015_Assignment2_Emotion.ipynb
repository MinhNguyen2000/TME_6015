# %% [markdown]
# # Emotion recognition with MobileNet
#
# In this portion of the assignment, I will leverage a pre-trained model (based on either the MobileNet or EfficientNet-B0) for the task of emotion recognition.
#
# **[Give an overview about the advantages and differences of the model]**

# %% [markdown]
# ## Import the libraries and dataset

# %%
from datasets import load_dataset               # Function to load a dataset from the HuggingFace database
import matplotlib.pyplot as plt
import numpy as np                              #
from numpy import round, sqrt 
from numpy import random                        # For showing a random array of images from the dataset
from PIL import Image

import tensorflow as tf
import keras
from keras import layers
from keras.applications import mobilenet, MobileNet

dataset_raw = load_dataset("FastJobs/Visual_Emotional_Analysis")
num_data = dataset_raw['train'].shape[0]

# Number of unique labels
num_classes = len(set(dataset_raw['train']['label']))
# Dimension of the input images (taken a single image)
image_dim = np.array(dataset_raw['train']['image'][0]).shape

# Dictionary to decode the meaning of the numerical labels
label_dict = {
    0: 'anger',
    1: 'contempt',
    2: 'disgust',
    3: 'fear',
    4: 'happy',
    5: 'neural',
    6: 'sad',
    7: 'suprise'
}
# Out:
# Resolving data files:   0%|          | 0/800 [00:00<?, ?it/s]

# %% [markdown]
# Make a train-test split to separate the training+validation data from the holdout set

# %%
dataset_split = dataset_raw['train'].train_test_split(test_size=0.2)

print(dataset_split)

num_train = len(dataset_split['train']['image'])
# num_train = dataset_split['train'].shape[0]
num_test = len(dataset_split['test']['image'])
# num_test = dataset_split['test'].shape[0]

# Print the number of samples in each set
print(f"There are {num_train} samples in the training set \n"
      f"There are {num_test} samples in the testing set")
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 640
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 160
#     })
# })
# There are 640 samples in the training set
# There are 160 samples in the testing set

# %% [markdown]
# ## Data discovery
# Display some examples from the training dataset

# %%
num_samples = 9                                                                             # number of samples to be display
num_rows = np.int8(round(sqrt(num_samples))); num_cols = np.int8(num_samples/num_rows)      # number of rows and columns for the subplot
rand = random.randint(num_train,size = (num_samples))                                       # random index for choosing the samples in the dataset

# Sample random images and their indices
image_rand = dataset_split['train'][rand]['image']
label_rand = dataset_split['train'][rand]['label']

fig, axes = plt.subplots(num_rows,num_cols,figsize=(num_rows*2,num_cols*2))

for i in range(num_rows):
    for j in range(num_cols):
        index = i * num_cols + j
        image = image_rand[index]  # Extract the image
        label = label_rand[index]  # Extract the label

        ax = axes[i,j]
        # Display the image
        ax.imshow(image)
        ax.set_title(f"Label: {label_dict[label]}")
        ax.axis("off")

# %% [markdown]
# To investigate the dimension of an image in this dataset, the image first need to be converted to a numpy array. The code block below shows that dimension of each image in terms of width x height x depth

# %%
# Let's take a random image from the sample
image = image_rand[random.randint(num_samples)]

# Dimension of the PIL image
print(f"The 2D size of the image is {image.size}\n"
      f"The depth of the image can be inferred from the image mode: {image.mode}\n")

# Dimension of the image_array
image_array = np.array(image)
image_dim = image_array.shape
print(f"Once converted to a numpy array, we can explicitly see the 3D size as \n{image_dim}")
# Out:
# The 2D size of the image is (96, 96)
# The depth of the image can be inferred from the image mode: RGB
#
# Once converted to a numpy array, we can explicitly see the 3D size as
# (96, 96, 3)

# %% [markdown]
# ## Data Unpacking

# %%
image_train_array = np.array(dataset_split['train']['image'])
label_train_array = np.array(dataset_split['train']['label'])

image_test_array = np.array(dataset_split['test']['image'])
label_test_array = np.array(dataset_split['test']['label'])

# %% [markdown]
# ## Image data augmentation layer
#
# Given that the model only has about 800 instances, I will perform data augmentation by applying some random transformation to the data. The goal of this layer is to present the pre-trained model with different transformation of each image every time the image is fed through the network. Thus, it does not overfit on certain feature extraction
# This is accomplished by adding some keras sequential layers that apply the transformation to the image before it is fed into the neural network.
#
# The code block belows show the construction of an image augmentation layer that will be added as the first layer of a pre-trained model.

# %%
keras.backend.clear_session()

image_augmentation = keras.Sequential([
    layers.Input(shape=(96,96,3)),
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.4),
    layers.RandomTranslation(0.1,0.1),
    layers.RandomZoom(0.1,0.1)
])

# %% [markdown]
# The data augmentation is visualized in the code block below. I will maintain the number of samples and the sample of images/labels from the start of this notebook for a comparison.

# %%
# Sample random images and their indices
image_rand_array = image_train_array[rand]
label_rand_array = label_train_array[rand]

fig, axes1 = plt.subplots(num_rows,num_cols,figsize=(num_rows*2,num_cols*2))
fig, axes2 = plt.subplots(num_rows,num_cols,figsize=(num_rows*2,num_cols*2))

for i in range(num_rows):
    for j in range(num_cols):
        index = i * num_cols + j
        image = image_rand_array[index]  # Extract the image
        label = label_rand_array[index]  # Extract the label
        
        # Original pictures (no augmentation layer applied)
        ax1 = axes1[i,j]
        ax1.axis("off")
        # Display the image
        ax1.imshow(image)
        ax1.set_title(f"Label: {label_dict[label]}")
        

        # Apply the augmentation layer on the image
        augmented_image = image_augmentation(tf.expand_dims(image, axis=0), training=True)/255

        ax2 = axes2[i,j]
        ax2.axis("off")
        # Display the image
        ax2.imshow(tf.squeeze(augmented_image).numpy())
        ax2.set_title(f"Label: {label_dict[label]}")
        

        plt.tight_layout()

# %% [markdown]
# ## Building the MobileNet-based model

# %% [markdown]
# ### MobileNet preprocessing

# %%
# Define the image augmentation layer
image_set_augmentation = keras.Sequential([
    layers.Input(shape=(96, 96, 3)),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    # layers.RandomTranslation(0.1, 0.1),
    # layers.RandomZoom(0.1, 0.1)
])

augmented_images = image_set_augmentation(image_train_array)
print(f"Dimension of the augmented training images: \n{augmented_images.shape}\n")

preprocessed_images = mobilenet.preprocess_input(augmented_images)
print(f"Dimension of the images after preprocessing for MobileNet: \n{preprocessed_images.shape}\n")

# Uncomment the following line to observe that the intensity of the pixels are normalized to [-1,1]
# print(preprocessed_images)
# Out:
# Dimension of the augmented training images:
# (640, 96, 96, 3)
#
# Dimension of the images after preprocessing for MobileNet:
# (640, 96, 96, 3)

# %% [markdown]
# ### MobileNet Base Model

# %%
base_model = MobileNet(input_shape=image_dim, 
                       include_top=False)
base_model.trainable = False
# base_model.summary()
# Out:
# C:\Users\caomi\AppData\Local\Temp\ipykernel_29032\3897284130.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNet(input_shape=image_dim,

# %% [markdown]
# ### Full Model

# %%
# Create the model
model = keras.Sequential([
    layers.Input(shape=image_dim),
    image_augmentation,                                 # Augment the training images
    layers.Lambda(mobilenet.preprocess_input),          # mobilenet preprocessing function
    base_model,                                         # MobileNet network
    layers.GlobalAveragePooling2D(),                    
    layers.Dropout(0.5),                                # To help with generalization
    layers.Dense(num_classes, activation="softmax")     # Custom classification layer
])

initial_weights = model.get_weights()

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenet_1.00_224 (Functional) │ (None, 3, 3, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │         8,200 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,237,064 (12.35 MB)
#  Trainable params: 8,200 (32.03 KB)
#  Non-trainable params: 3,228,864 (12.32 MB)

# %%
len(model.trainable_variables)
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# ### Model Training

# %% [markdown]
# Before any training, the accuracy of the model is fairly poor and is no better than random chance (1/8=12.5%)

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.005),
              loss=keras.losses.SparseCategoricalCrossentropy,
              metrics=["accuracy"])
loss0, acc0 = model.evaluate(image_train_array,label_train_array)

print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(acc0))
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.1099 - loss: 3.7156
# initial loss: 3.65
# initial accuracy: 0.12

# %%
# Intitial training with frozen base model
initial_lr = 0.0005
initial_batch_size = 32
initial_epochs = 100



model.set_weights(initial_weights)

# # Learning rate scheduler
# initial_lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=initial_lr,
#     decay_steps=1000,
#     decay_rate=0.5
# )
base_model.trainable = False
model.compile(optimizer=keras.optimizers.Adam(learning_rate=initial_lr),
              loss=keras.losses.SparseCategoricalCrossentropy,
              metrics=["accuracy"])
model.summary()

history_initial = model.fit(image_train_array,
                    label_train_array,
                    epochs=initial_epochs,
                    batch_size=initial_batch_size,
                    validation_split=0.2,
                    verbose=2)

# Fine tuning by unfreezing some later layers of MobileNet
ftune_lr = 0.00005
ftune_batch_size = 16
ftune_epochs = 50
unfrozen_layer = 100

base_model.trainable = True

for layer in base_model.layers[:unfrozen_layer]:
    layer.trainable = False

# Learning rate scheduler
ftune_lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=ftune_lr,
    decay_steps=1000,
    decay_rate=0.5
)

model.compile(optimizer=keras.optimizers.Adam(learning_rate=ftune_lr_scheduler),
              loss=keras.losses.SparseCategoricalCrossentropy,
              metrics=["accuracy"])
model.summary()

history_fine = model.fit(image_train_array, 
                         label_train_array, 
                         epochs=initial_epochs + ftune_epochs,
                         validation_split=0.2,
                         initial_epoch=history_initial.epoch[-1],       # Resume from previous training
                         verbose = 2)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenet_1.00_224 (Functional) │ (None, 3, 3, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │         8,200 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,237,064 (12.35 MB)
#  Trainable params: 8,200 (32.03 KB)
#  Non-trainable params: 3,228,864 (12.32 MB)
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.1464 - loss: 4.7525 - val_accuracy: 0.1484 - val_loss: 2.8837
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.1298 - loss: 4.3078 - val_accuracy: 0.1406 - val_loss: 2.8516
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.1574 - loss: 3.9422 - val_accuracy: 0.1562 - val_loss: 2.7207
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2119 - loss: 3.8714 - val_accuracy: 0.1406 - val_loss: 2.6967
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.1743 - loss: 3.9037 - val_accuracy: 0.1484 - val_loss: 2.5768
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2105 - loss: 3.3377 - val_accuracy: 0.1719 - val_loss: 2.5123
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.1848 - loss: 3.4772 - val_accuracy: 0.1875 - val_loss: 2.5094
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.1442 - loss: 3.8644 - val_accuracy: 0.1875 - val_loss: 2.4913
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.2102 - loss: 3.2912 - val_accuracy: 0.1641 - val_loss: 2.4052
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2201 - loss: 3.1866 - val_accuracy: 0.1953 - val_loss: 2.4589
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2417 - loss: 3.1045 - val_accuracy: 0.1953 - val_loss: 2.4557
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2605 - loss: 2.9542 - val_accuracy: 0.2188 - val_loss: 2.3551
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.2328 - loss: 3.0782 - val_accuracy: 0.2188 - val_loss: 2.3550
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2393 - loss: 3.1332 - val_accuracy: 0.2031 - val_loss: 2.3505
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.2413 - loss: 2.9898 - val_accuracy: 0.1953 - val_loss: 2.3893
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2327 - loss: 2.9034 - val_accuracy: 0.2109 - val_loss: 2.3238
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3211 - loss: 2.7605 - val_accuracy: 0.1953 - val_loss: 2.3298
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.1959 - loss: 3.0112 - val_accuracy: 0.2031 - val_loss: 2.3563
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.2606 - loss: 2.8981 - val_accuracy: 0.2031 - val_loss: 2.3135
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.3140 - loss: 2.5363 - val_accuracy: 0.2109 - val_loss: 2.2141
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2706 - loss: 2.8984 - val_accuracy: 0.2109 - val_loss: 2.2931
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.2879 - loss: 2.6451 - val_accuracy: 0.2344 - val_loss: 2.1828
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2801 - loss: 2.5098 - val_accuracy: 0.2188 - val_loss: 2.3384
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2953 - loss: 2.5942 - val_accuracy: 0.2422 - val_loss: 2.2207
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.2665 - loss: 2.4736 - val_accuracy: 0.2266 - val_loss: 2.1610
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3057 - loss: 2.3907 - val_accuracy: 0.2344 - val_loss: 2.2123
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.3399 - loss: 2.4167 - val_accuracy: 0.2109 - val_loss: 2.2056
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.3075 - loss: 2.3729 - val_accuracy: 0.2344 - val_loss: 2.1313
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2988 - loss: 2.3991 - val_accuracy: 0.2422 - val_loss: 2.1649
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.3307 - loss: 2.2166 - val_accuracy: 0.2422 - val_loss: 2.2559
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.3184 - loss: 2.1848 - val_accuracy: 0.2422 - val_loss: 2.1568
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3189 - loss: 2.3901 - val_accuracy: 0.2422 - val_loss: 2.1967
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.3424 - loss: 2.2022 - val_accuracy: 0.2422 - val_loss: 2.1756
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.3450 - loss: 2.2326 - val_accuracy: 0.2266 - val_loss: 2.1918
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.2980 - loss: 2.1202 - val_accuracy: 0.2344 - val_loss: 2.1794
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.3435 - loss: 2.1027 - val_accuracy: 0.2109 - val_loss: 2.2160
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3187 - loss: 2.1971 - val_accuracy: 0.2344 - val_loss: 2.1823
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2857 - loss: 2.1690 - val_accuracy: 0.2109 - val_loss: 2.2038
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3446 - loss: 2.0562 - val_accuracy: 0.2188 - val_loss: 2.2037
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3688 - loss: 1.9509 - val_accuracy: 0.2422 - val_loss: 2.2408
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3668 - loss: 2.0307 - val_accuracy: 0.2266 - val_loss: 2.1843
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3369 - loss: 1.9609 - val_accuracy: 0.2266 - val_loss: 2.1788
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3624 - loss: 1.9455 - val_accuracy: 0.2422 - val_loss: 2.1477
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3611 - loss: 2.0067 - val_accuracy: 0.2188 - val_loss: 2.1692
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3340 - loss: 2.0726 - val_accuracy: 0.2109 - val_loss: 2.1295
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.3359 - loss: 2.0354 - val_accuracy: 0.2109 - val_loss: 2.1371
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3717 - loss: 2.0090 - val_accuracy: 0.2188 - val_loss: 2.1843
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3580 - loss: 1.9882 - val_accuracy: 0.2188 - val_loss: 2.1572
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4237 - loss: 1.7139 - val_accuracy: 0.2344 - val_loss: 2.1899
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3657 - loss: 1.8943 - val_accuracy: 0.2500 - val_loss: 2.1132
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3778 - loss: 1.8820 - val_accuracy: 0.2422 - val_loss: 2.1841
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3630 - loss: 1.8700 - val_accuracy: 0.2266 - val_loss: 2.1542
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4113 - loss: 1.8108 - val_accuracy: 0.2344 - val_loss: 2.1465
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.3897 - loss: 1.7089 - val_accuracy: 0.2344 - val_loss: 2.1908
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3778 - loss: 1.7757 - val_accuracy: 0.2500 - val_loss: 2.0356
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4067 - loss: 1.6730 - val_accuracy: 0.2266 - val_loss: 2.0636
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3765 - loss: 1.8105 - val_accuracy: 0.2422 - val_loss: 2.1052
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4048 - loss: 1.7127 - val_accuracy: 0.2344 - val_loss: 2.1357
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3942 - loss: 1.8002 - val_accuracy: 0.2422 - val_loss: 2.0872
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3984 - loss: 1.8147 - val_accuracy: 0.2422 - val_loss: 2.1432
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4342 - loss: 1.7569 - val_accuracy: 0.2109 - val_loss: 2.1119
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4042 - loss: 1.7490 - val_accuracy: 0.2266 - val_loss: 2.1334
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4209 - loss: 1.6928 - val_accuracy: 0.2344 - val_loss: 2.1255
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4200 - loss: 1.7374 - val_accuracy: 0.2656 - val_loss: 2.1260
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3945 - loss: 1.7012 - val_accuracy: 0.2344 - val_loss: 2.1165
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4601 - loss: 1.5217 - val_accuracy: 0.2188 - val_loss: 2.1080
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3806 - loss: 1.7266 - val_accuracy: 0.2422 - val_loss: 2.1208
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3770 - loss: 1.7696 - val_accuracy: 0.1953 - val_loss: 2.1088
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4150 - loss: 1.6360 - val_accuracy: 0.2578 - val_loss: 2.0874
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3924 - loss: 1.6872 - val_accuracy: 0.2031 - val_loss: 2.1193
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4478 - loss: 1.5434 - val_accuracy: 0.2031 - val_loss: 2.1358
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4315 - loss: 1.6597 - val_accuracy: 0.2500 - val_loss: 2.0871
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4576 - loss: 1.5311 - val_accuracy: 0.2344 - val_loss: 2.1247
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4669 - loss: 1.6118 - val_accuracy: 0.2578 - val_loss: 2.0847
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4032 - loss: 1.7061 - val_accuracy: 0.2500 - val_loss: 2.0750
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4735 - loss: 1.5726 - val_accuracy: 0.1875 - val_loss: 2.1511
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4212 - loss: 1.6100 - val_accuracy: 0.2422 - val_loss: 2.0973
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4508 - loss: 1.5183 - val_accuracy: 0.2422 - val_loss: 2.0767
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4925 - loss: 1.5013 - val_accuracy: 0.2109 - val_loss: 2.0762
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4560 - loss: 1.5675 - val_accuracy: 0.2188 - val_loss: 2.1008
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4874 - loss: 1.5742 - val_accuracy: 0.2422 - val_loss: 2.0909
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4479 - loss: 1.5477 - val_accuracy: 0.2422 - val_loss: 2.1270
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4681 - loss: 1.4520 - val_accuracy: 0.2344 - val_loss: 2.0585
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4733 - loss: 1.5539 - val_accuracy: 0.2344 - val_loss: 2.1243
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3726 - loss: 1.6020 - val_accuracy: 0.2188 - val_loss: 2.0631
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4246 - loss: 1.5142 - val_accuracy: 0.2422 - val_loss: 2.0465
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4525 - loss: 1.5152 - val_accuracy: 0.2188 - val_loss: 2.1322
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4678 - loss: 1.4654 - val_accuracy: 0.2188 - val_loss: 2.0983
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4520 - loss: 1.5642 - val_accuracy: 0.2500 - val_loss: 2.0225
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4131 - loss: 1.6984 - val_accuracy: 0.2109 - val_loss: 2.1087
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5172 - loss: 1.4050 - val_accuracy: 0.2656 - val_loss: 2.0131
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4141 - loss: 1.5822 - val_accuracy: 0.2422 - val_loss: 2.0803
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4496 - loss: 1.5069 - val_accuracy: 0.2969 - val_loss: 2.0889
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4749 - loss: 1.5521 - val_accuracy: 0.2578 - val_loss: 2.0518
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4901 - loss: 1.5043 - val_accuracy: 0.2578 - val_loss: 2.0741
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4391 - loss: 1.5321 - val_accuracy: 0.2422 - val_loss: 2.0587
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4588 - loss: 1.5322 - val_accuracy: 0.2734 - val_loss: 2.0775
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4716 - loss: 1.4713 - val_accuracy: 0.2500 - val_loss: 2.0672
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.4632 - loss: 1.4625 - val_accuracy: 0.2578 - val_loss: 2.0204
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4841 - loss: 1.5288 - val_accuracy: 0.2656 - val_loss: 2.0368
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenet_1.00_224 (Functional) │ (None, 3, 3, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │         8,200 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,237,064 (12.35 MB)
#  Trainable params: 8,200 (32.03 KB)
#  Non-trainable params: 3,228,864 (12.32 MB)
# Epoch 100/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.4724 - loss: 1.3988 - val_accuracy: 0.2812 - val_loss: 2.0322
# Epoch 101/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.4470 - loss: 1.4970 - val_accuracy: 0.2812 - val_loss: 2.0248
# Epoch 102/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4743 - loss: 1.4309 - val_accuracy: 0.2812 - val_loss: 2.0308
# Epoch 103/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5104 - loss: 1.3811 - val_accuracy: 0.2734 - val_loss: 2.0225
# Epoch 104/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4489 - loss: 1.4322 - val_accuracy: 0.2812 - val_loss: 2.0227
# Epoch 105/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4526 - loss: 1.5022 - val_accuracy: 0.2734 - val_loss: 2.0321
# Epoch 106/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4337 - loss: 1.5464 - val_accuracy: 0.2734 - val_loss: 2.0315
# Epoch 107/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4431 - loss: 1.5451 - val_accuracy: 0.2812 - val_loss: 2.0288
# Epoch 108/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4605 - loss: 1.4760 - val_accuracy: 0.2891 - val_loss: 2.0283
# Epoch 109/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4635 - loss: 1.4360 - val_accuracy: 0.2734 - val_loss: 2.0379
# Epoch 110/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.5231 - loss: 1.3444 - val_accuracy: 0.2812 - val_loss: 2.0403
# Epoch 111/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5108 - loss: 1.3711 - val_accuracy: 0.2812 - val_loss: 2.0423
# Epoch 112/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4493 - loss: 1.5397 - val_accuracy: 0.2812 - val_loss: 2.0443
# Epoch 113/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4682 - loss: 1.4768 - val_accuracy: 0.2812 - val_loss: 2.0461
# Epoch 114/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4950 - loss: 1.5181 - val_accuracy: 0.2812 - val_loss: 2.0413
# Epoch 115/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.4425 - loss: 1.5202 - val_accuracy: 0.2812 - val_loss: 2.0399
# Epoch 116/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4482 - loss: 1.5018 - val_accuracy: 0.2812 - val_loss: 2.0403
# Epoch 117/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4990 - loss: 1.4051 - val_accuracy: 0.2812 - val_loss: 2.0382
# Epoch 118/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5306 - loss: 1.4267 - val_accuracy: 0.2812 - val_loss: 2.0390
# Epoch 119/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4866 - loss: 1.4954 - val_accuracy: 0.2734 - val_loss: 2.0380
# Epoch 120/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4822 - loss: 1.4523 - val_accuracy: 0.2734 - val_loss: 2.0338
# Epoch 121/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.4357 - loss: 1.4755 - val_accuracy: 0.2734 - val_loss: 2.0304
# Epoch 122/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4814 - loss: 1.5195 - val_accuracy: 0.2969 - val_loss: 2.0192
# Epoch 123/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4642 - loss: 1.4994 - val_accuracy: 0.2969 - val_loss: 2.0257
# Epoch 124/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.4323 - loss: 1.5185 - val_accuracy: 0.2812 - val_loss: 2.0321
# Epoch 125/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.4718 - loss: 1.4071 - val_accuracy: 0.2891 - val_loss: 2.0315
# Epoch 126/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4455 - loss: 1.4939 - val_accuracy: 0.2812 - val_loss: 2.0352
# Epoch 127/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4918 - loss: 1.4146 - val_accuracy: 0.2812 - val_loss: 2.0401
# Epoch 128/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4619 - loss: 1.4724 - val_accuracy: 0.2734 - val_loss: 2.0392
# Epoch 129/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4456 - loss: 1.4814 - val_accuracy: 0.2734 - val_loss: 2.0425
# Epoch 130/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.4945 - loss: 1.4060 - val_accuracy: 0.2812 - val_loss: 2.0375
# Epoch 131/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.4974 - loss: 1.3719 - val_accuracy: 0.2734 - val_loss: 2.0421
# Epoch 132/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.4288 - loss: 1.5527 - val_accuracy: 0.2734 - val_loss: 2.0418
# Epoch 133/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.4542 - loss: 1.4988 - val_accuracy: 0.2734 - val_loss: 2.0400
# Epoch 134/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4864 - loss: 1.4472 - val_accuracy: 0.2891 - val_loss: 2.0424
# Epoch 135/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4764 - loss: 1.4896 - val_accuracy: 0.2891 - val_loss: 2.0427
# Epoch 136/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5234 - loss: 1.3753 - val_accuracy: 0.2734 - val_loss: 2.0434
# Epoch 137/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5186 - loss: 1.3492 - val_accuracy: 0.2891 - val_loss: 2.0412
# Epoch 138/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5037 - loss: 1.3950 - val_accuracy: 0.2812 - val_loss: 2.0465
# Epoch 139/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4770 - loss: 1.4777 - val_accuracy: 0.2812 - val_loss: 2.0384
# Epoch 140/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4796 - loss: 1.5423 - val_accuracy: 0.2891 - val_loss: 2.0306
# Epoch 141/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.4934 - loss: 1.4075 - val_accuracy: 0.2812 - val_loss: 2.0313
# Epoch 142/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.4553 - loss: 1.4216 - val_accuracy: 0.2812 - val_loss: 2.0353
# Epoch 143/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4555 - loss: 1.4243 - val_accuracy: 0.2734 - val_loss: 2.0350
# Epoch 144/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5281 - loss: 1.3443 - val_accuracy: 0.2891 - val_loss: 2.0373
# Epoch 145/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.5251 - loss: 1.3530 - val_accuracy: 0.2891 - val_loss: 2.0366
# Epoch 146/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4083 - loss: 1.5431 - val_accuracy: 0.2891 - val_loss: 2.0339
# Epoch 147/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.4796 - loss: 1.5116 - val_accuracy: 0.2891 - val_loss: 2.0321
# Epoch 148/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4481 - loss: 1.5143 - val_accuracy: 0.2891 - val_loss: 2.0332
# Epoch 149/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4889 - loss: 1.4552 - val_accuracy: 0.2812 - val_loss: 2.0351
# Epoch 150/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5560 - loss: 1.3251 - val_accuracy: 0.2812 - val_loss: 2.0380

# %%
def plot_performance(history, learning_rate=None, batch_size=None, finetune_epochs=None):
  plt.figure(figsize=(10,5))

  

  # Determine whether history is keras history or a dictionary to appropriately extract the history data
  if isinstance(history, keras.src.callbacks.history.History):
    history_data = history.history        # Extract the history dictionary
  else:
    history_data = history                # Assume it's already a dictionary

  # Accuracy of model training and validation vs training epoch
  plt.subplot(1,2,1)
  ylim_acc = [0, max(max(history_data['accuracy']),max(history_data['val_accuracy']))]
  plt.plot(history_data['accuracy'], label = 'Training accuracy')
  plt.plot(history_data['val_accuracy'], label = 'Validation accuracy')
  plt.ylim(ylim_acc)
  if finetune_epochs:
    plt.plot([finetune_epochs-1, finetune_epochs-1],plt.ylim(), label = 'Fine tuning')
  else:
    pass

  if learning_rate and batch_size:
    plt.title(f'Model accuracy \n lr = {learning_rate}, batch size = {batch_size}')
  else: plt.title('Model accuracy')

  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(loc='lower right')

  # Loss during model training and validation
  plt.subplot(1,2,2)
  ylim_loss = [0, max(max(history_data['loss']),max(history_data['val_loss']))]
  # print(len(history_data['loss']))
  plt.plot(history_data['loss'], label = 'Training loss')
  plt.plot(history_data['val_loss'], label = 'Validation loss')
  plt.ylim(ylim_loss)
  if finetune_epochs:
    plt.plot([finetune_epochs-1, finetune_epochs-1],plt.ylim(), label = 'Fine tuning')
  else:
    pass

  if learning_rate and batch_size:
    plt.title(f'Model loss \n lr = {learning_rate}, batch size = {batch_size}')
  else: plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(loc='lower right')
  plt.show()

  print(f"The model has a training accuracy of {history_data['accuracy'][-1]*100:.2f}%\n"
      f"The model has a validation accuracy of {history_data['val_accuracy'][-1]*100:.2f}%")
  return

# %%
combined_history = {
    'accuracy': history_initial.history['accuracy'] + history_fine.history['accuracy'],
    'val_accuracy': history_initial.history['val_accuracy'] + history_fine.history['val_accuracy'],
    'loss': history_initial.history['loss'] + history_fine.history['loss'],
    'val_loss': history_initial.history['val_loss'] + history_fine.history['val_loss']
}

plot_performance(combined_history,finetune_epochs=initial_epochs)
# Out:
# The model has a training accuracy of 53.52%
# The model has a validation accuracy of 28.12%

# %% [markdown]
# ## Model evaluation and prediction

# %% [markdown]
# ### Model evaluation

# %%
test_loss, test_acc =  model.evaluate(image_test_array,label_test_array)
print(f"Test accuracy: {test_acc}\n"
      f"Test loss: {test_loss}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2782 - loss: 2.0185
# Test accuracy: 0.28125
# Test loss: 2.0037834644317627

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

prediction_array = np.argmax(model.predict(image_test_array), axis=1)

cm = confusion_matrix(label_test_array, prediction_array)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)  # You can change the color map as desired
plt.title("Confusion Matrix")
plt.show()
print(label_dict)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# {0: 'anger', 1: 'contempt', 2: 'disgust', 3: 'fear', 4: 'happy', 5: 'neural', 6: 'sad', 7: 'suprise'}

# %% [markdown]
# ### Model prediction & visualization

# %%
# Sample random images and their indices
num_samples = 25                                                                             # number of samples to be display
num_rows = int(round(sqrt(num_samples))); num_cols = int(num_samples/num_rows)      # number of rows and columns for the subplot
rand = random.randint(num_test,size = (num_samples))                                       # random index for choosing the samples in the dataset

image_test_rand_array = image_test_array[rand]
label_test_rand_array = label_test_array[rand]
prediction_rand_array = np.argmax(model.predict(image_test_rand_array),axis=1)

plt.figure(figsize=(num_rows*2,num_cols*2))
# fig, axes1 = plt.subplots(num_rows,num_cols,figsize=(num_rows*2,num_cols*2))

for i in range(num_rows):
    for j in range(num_cols):
        index = i * num_cols + j
        plt.subplot(num_rows,num_cols,index+1)
        image = image_test_rand_array[index]  # Extract the image
        label = label_test_rand_array[index]  # Extract the label
        prediction = prediction_rand_array[index]

        # Original pictures (no augmentation layer applied)
        plt.axis("off")
        # Display the image
        plt.imshow(image)
        plt.title(f"Label: {label_dict[label]}\n"
                  f"Predict: {label_dict[prediction]}",
                  fontsize = 8) 

plt.tight_layout()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
