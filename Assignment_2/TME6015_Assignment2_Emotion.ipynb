# %% [markdown]
# # Emotion recognition with MobileNet
#
# In this portion of the assignment, I will leverage a pre-trained model (based on either the MobileNet or EfficientNet-B0) for the task of emotion recognition.
#
# **[Give an overview about the advantages and differences of the model]**

# %% [markdown]
# ## Import the libraries and dataset

# %%
from datasets import load_dataset               # Function to load a dataset from the HuggingFace database
import matplotlib.pyplot as plt
import numpy as np                              #
from numpy import round, sqrt 
from numpy import random                        # For showing a random array of images from the dataset
from PIL import Image

import tensorflow as tf
import keras
from keras import layers
from keras.applications import mobilenet, MobileNet

dataset_raw = load_dataset("FastJobs/Visual_Emotional_Analysis")
num_data = dataset_raw['train'].shape[0]

# Number of unique labels
num_classes = len(set(dataset_raw['train']['label']))
# Dimension of the input images (taken a single image)
image_dim = np.array(dataset_raw['train']['image'][0]).shape

# Dictionary to decode the meaning of the numerical labels
label_dict = {
    0: 'anger',
    1: 'contempt',
    2: 'disgust',
    3: 'fear',
    4: 'happy',
    5: 'neutral',
    6: 'sad',
    7: 'suprise'
}
# Out:
# Resolving data files:   0%|          | 0/800 [00:00<?, ?it/s]

# %% [markdown]
# Make a train-test split to separate the training+validation data from the holdout set

# %%
dataset_split = dataset_raw['train'].train_test_split(test_size=0.2)

print(dataset_split)

num_train = len(dataset_split['train']['image'])
# num_train = dataset_split['train'].shape[0]
num_test = len(dataset_split['test']['image'])
# num_test = dataset_split['test'].shape[0]

# Print the number of samples in each set
print(f"There are {num_train} samples in the training set \n"
      f"There are {num_test} samples in the testing set")
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 640
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 160
#     })
# })
# There are 640 samples in the training set
# There are 160 samples in the testing set

# %% [markdown]
# ## Data discovery
# Display some examples from the training dataset

# %%
num_samples = 9                                                                             # number of samples to be display
num_rows = np.int8(round(sqrt(num_samples))); num_cols = np.int8(num_samples/num_rows)      # number of rows and columns for the subplot
rand = random.randint(num_train,size = (num_samples))                                       # random index for choosing the samples in the dataset

# Sample random images and their indices
image_rand = dataset_split['train'][rand]['image']
label_rand = dataset_split['train'][rand]['label']

fig, axes = plt.subplots(num_rows,num_cols,figsize=(num_rows*2,num_cols*2))

for i in range(num_rows):
    for j in range(num_cols):
        index = i * num_cols + j
        image = image_rand[index]  # Extract the image
        label = label_rand[index]  # Extract the label

        ax = axes[i,j]
        # Display the image
        ax.imshow(image)
        ax.set_title(f"Label: {label_dict[label]}")
        ax.axis("off")

# %% [markdown]
# To investigate the dimension of an image in this dataset, the image first need to be converted to a numpy array. The code block below shows that dimension of each image in terms of width x height x depth

# %%
# Let's take a random image from the sample
image = image_rand[random.randint(num_samples)]

# Dimension of the PIL image
print(f"The 2D size of the image is {image.size}\n"
      f"The depth of the image can be inferred from the image mode: {image.mode}\n")

# Dimension of the image_array
image_array = np.array(image)
image_dim = image_array.shape
print(f"Once converted to a numpy array, we can explicitly see the 3D size as \n{image_dim}")
# Out:
# The 2D size of the image is (96, 96)
# The depth of the image can be inferred from the image mode: RGB
#
# Once converted to a numpy array, we can explicitly see the 3D size as
# (96, 96, 3)

# %% [markdown]
# ## Data Unpacking

# %%
image_train_array = np.array(dataset_split['train']['image'])
label_train_array = np.array(dataset_split['train']['label'])

image_test_array = np.array(dataset_split['test']['image'])
label_test_array = np.array(dataset_split['test']['label'])

# %% [markdown]
# ## Image data augmentation layer
#
# Given that the model only has about 800 instances, I will perform data augmentation by applying some random transformation to the data. The goal of this layer is to present the pre-trained model with different transformation of each image every time the image is fed through the network. Thus, it does not overfit on certain feature extraction
# This is accomplished by adding some keras sequential layers that apply the transformation to the image before it is fed into the neural network.
#
# The code block belows show the construction of an image augmentation layer that will be added as the first layer of a pre-trained model.

# %%
keras.backend.clear_session()

image_augmentation = keras.Sequential([
    layers.Input(shape=(96,96,3)),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    # layers.RandomTranslation(0.1,0.1),
    # layers.RandomZoom(0.1,0.1)
])
# Out:
# WARNING:tensorflow:From c:\mnguyen\TME_6015\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %% [markdown]
# The data augmentation is visualized in the code block below. I will maintain the number of samples and the sample of images/labels from the start of this notebook for a comparison.

# %%
# Sample random images and their indices
image_rand_array = image_train_array[rand]
label_rand_array = label_train_array[rand]

fig, axes1 = plt.subplots(num_rows,num_cols,figsize=(num_rows*2,num_cols*2))
fig, axes2 = plt.subplots(num_rows,num_cols,figsize=(num_rows*2,num_cols*2))

for i in range(num_rows):
    for j in range(num_cols):
        index = i * num_cols + j
        image = image_rand_array[index]  # Extract the image
        label = label_rand_array[index]  # Extract the label
        
        # Original pictures (no augmentation layer applied)
        ax1 = axes1[i,j]
        ax1.axis("off")
        # Display the image
        ax1.imshow(image)
        ax1.set_title(f"Label: {label_dict[label]}")
        

        # Apply the augmentation layer on the image
        augmented_image = image_augmentation(tf.expand_dims(image, axis=0), training=True)/255

        ax2 = axes2[i,j]
        ax2.axis("off")
        # Display the image
        ax2.imshow(tf.squeeze(augmented_image).numpy())
        ax2.set_title(f"Label: {label_dict[label]}")
        

plt.tight_layout()

# %% [markdown]
# ## Building the MobileNet-based model

# %% [markdown]
# ### MobileNet preprocessing

# %%
# Define the image augmentation layer
image_set_augmentation = keras.Sequential([
    layers.Input(shape=(96, 96, 3)),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    # layers.RandomTranslation(0.1, 0.1),
    # layers.RandomZoom(0.1, 0.1)
])

augmented_images = image_set_augmentation(image_train_array)
print(f"Dimension of the augmented training images: \n{augmented_images.shape}\n")

preprocessed_images = mobilenet.preprocess_input(augmented_images)
print(f"Dimension of the images after preprocessing for MobileNet: \n{preprocessed_images.shape}\n")

# Uncomment the following line to observe that the intensity of the pixels are normalized to [-1,1]
# print(preprocessed_images)
# Out:
# Dimension of the augmented training images:
# (640, 96, 96, 3)
#
# Dimension of the images after preprocessing for MobileNet:
# (640, 96, 96, 3)

# %% [markdown]
# ### MobileNet Base Model

# %%
base_model = MobileNet(input_shape=image_dim, 
                       include_top=False)
base_model.trainable = False
# base_model.summary()
# Out:
# C:\Users\mnguyen6\AppData\Local\Temp\ipykernel_19348\3897284130.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNet(input_shape=image_dim,

# %% [markdown]
# ### Full Model

# %%
# Create the model
model = keras.Sequential([
    layers.Input(shape=image_dim),
    image_augmentation,                                 # Augment the training images
    layers.Lambda(mobilenet.preprocess_input),          # mobilenet preprocessing function
    base_model,                                         # MobileNet network
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),                    
    layers.Dropout(0.5),                                # To help with generalization
    layers.Dense(num_classes, activation="softmax")     # Custom classification layer
])

initial_weights = model.get_weights()

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenet_1.00_224 (Functional) │ (None, 3, 3, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │         8,200 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,237,064 (12.35 MB)
#  Trainable params: 8,200 (32.03 KB)
#  Non-trainable params: 3,228,864 (12.32 MB)

# %%
len(model.trainable_variables)
keras.utils.plot_model(model,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# ### Model Training

# %% [markdown]
# Before any training, the accuracy of the model is fairly poor and is no better than random chance (1/8=12.5%)

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.005),
              loss=keras.losses.SparseCategoricalCrossentropy,
              metrics=["accuracy"])
loss0, acc0 = model.evaluate(image_train_array,label_train_array)

print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(acc0))
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.1084 - loss: 3.5760
# initial loss: 3.54
# initial accuracy: 0.11

# %%
# Intitial training with frozen base model
initial_lr = 0.0005
initial_batch_size = 32
initial_epochs = 150



model.set_weights(initial_weights)

# # Learning rate scheduler
# initial_lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=initial_lr,
#     decay_steps=1000,
#     decay_rate=0.5
# )
base_model.trainable = False
model.compile(optimizer=keras.optimizers.Adam(learning_rate=initial_lr),
              loss=keras.losses.SparseCategoricalCrossentropy,
              metrics=["accuracy"])
model.summary()

history_initial = model.fit(image_train_array,
                    label_train_array,
                    epochs=initial_epochs,
                    batch_size=initial_batch_size,
                    validation_split=0.2,
                    verbose=2)

# Fine tuning by unfreezing some later layers of MobileNet
ftune_lr = 0.00005
ftune_batch_size = 16
ftune_epochs = 150
unfrozen_layer = 100

base_model.trainable = True

for layer in base_model.layers[:unfrozen_layer]:
    layer.trainable = False

# Learning rate scheduler
ftune_lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=ftune_lr,
    decay_steps=1000,
    decay_rate=0.5
)

model.compile(optimizer=keras.optimizers.Adam(learning_rate=ftune_lr_scheduler),
              loss=keras.losses.SparseCategoricalCrossentropy,
              metrics=["accuracy"])
model.summary()

history_fine = model.fit(image_train_array, 
                         label_train_array, 
                         epochs=initial_epochs + ftune_epochs,
                         validation_split=0.2,
                         initial_epoch=history_initial.epoch[-1],       # Resume from previous training
                         verbose = 2)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenet_1.00_224 (Functional) │ (None, 3, 3, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │         8,200 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,237,064 (12.35 MB)
#  Trainable params: 8,200 (32.03 KB)
#  Non-trainable params: 3,228,864 (12.32 MB)
# Epoch 1/150
# 16/16 - 2s - 116ms/step - accuracy: 0.1348 - loss: 4.3403 - val_accuracy: 0.1562 - val_loss: 2.9565
# Epoch 2/150
# 16/16 - 0s - 31ms/step - accuracy: 0.1641 - loss: 4.1744 - val_accuracy: 0.1797 - val_loss: 2.9083
# Epoch 3/150
# 16/16 - 0s - 30ms/step - accuracy: 0.1777 - loss: 3.6472 - val_accuracy: 0.1719 - val_loss: 2.6259
# Epoch 4/150
# 16/16 - 0s - 31ms/step - accuracy: 0.1758 - loss: 3.6131 - val_accuracy: 0.1875 - val_loss: 2.5131
# Epoch 5/150
# 16/16 - 0s - 31ms/step - accuracy: 0.1934 - loss: 3.3901 - val_accuracy: 0.2031 - val_loss: 2.4972
# Epoch 6/150
# 16/16 - 0s - 31ms/step - accuracy: 0.2051 - loss: 3.3537 - val_accuracy: 0.1797 - val_loss: 2.4276
# Epoch 7/150
# 16/16 - 1s - 32ms/step - accuracy: 0.2285 - loss: 3.1753 - val_accuracy: 0.2109 - val_loss: 2.4237
# Epoch 8/150
# 16/16 - 1s - 32ms/step - accuracy: 0.2363 - loss: 3.0548 - val_accuracy: 0.2422 - val_loss: 2.3628
# Epoch 9/150
# 16/16 - 1s - 32ms/step - accuracy: 0.2422 - loss: 2.9859 - val_accuracy: 0.1953 - val_loss: 2.2777
# Epoch 10/150
# 16/16 - 1s - 32ms/step - accuracy: 0.2246 - loss: 2.9758 - val_accuracy: 0.2266 - val_loss: 2.2583
# Epoch 11/150
# 16/16 - 1s - 32ms/step - accuracy: 0.2832 - loss: 2.7050 - val_accuracy: 0.2109 - val_loss: 2.3018
# Epoch 12/150
# 16/16 - 1s - 31ms/step - accuracy: 0.2363 - loss: 2.7717 - val_accuracy: 0.2188 - val_loss: 2.2258
# Epoch 13/150
# 16/16 - 0s - 31ms/step - accuracy: 0.2734 - loss: 2.7065 - val_accuracy: 0.2422 - val_loss: 2.1400
# Epoch 14/150
# 16/16 - 0s - 31ms/step - accuracy: 0.2852 - loss: 2.5339 - val_accuracy: 0.2266 - val_loss: 2.1501
# Epoch 15/150
# 16/16 - 0s - 30ms/step - accuracy: 0.2754 - loss: 2.4594 - val_accuracy: 0.2656 - val_loss: 2.1265
# Epoch 16/150
# 16/16 - 0s - 30ms/step - accuracy: 0.3066 - loss: 2.4157 - val_accuracy: 0.3125 - val_loss: 2.0910
# Epoch 17/150
# 16/16 - 0s - 30ms/step - accuracy: 0.2734 - loss: 2.5385 - val_accuracy: 0.2734 - val_loss: 2.1092
# Epoch 18/150
# 16/16 - 0s - 30ms/step - accuracy: 0.3320 - loss: 2.2825 - val_accuracy: 0.2656 - val_loss: 2.0931
# Epoch 19/150
# 16/16 - 0s - 31ms/step - accuracy: 0.3242 - loss: 2.2915 - val_accuracy: 0.2891 - val_loss: 2.0722
# Epoch 20/150
# 16/16 - 0s - 31ms/step - accuracy: 0.3125 - loss: 2.2597 - val_accuracy: 0.2891 - val_loss: 2.0392
# Epoch 21/150
# 16/16 - 0s - 30ms/step - accuracy: 0.2715 - loss: 2.3384 - val_accuracy: 0.2969 - val_loss: 2.0583
# Epoch 22/150
# 16/16 - 0s - 31ms/step - accuracy: 0.3320 - loss: 2.2368 - val_accuracy: 0.2891 - val_loss: 2.0522
# Epoch 23/150
# 16/16 - 0s - 30ms/step - accuracy: 0.3184 - loss: 2.3323 - val_accuracy: 0.2656 - val_loss: 2.0383
# Epoch 24/150
# 16/16 - 0s - 31ms/step - accuracy: 0.3066 - loss: 2.3871 - val_accuracy: 0.3125 - val_loss: 2.0113
# Epoch 25/150
# 16/16 - 0s - 30ms/step - accuracy: 0.3926 - loss: 2.0190 - val_accuracy: 0.3203 - val_loss: 2.0071
# Epoch 26/150
# 16/16 - 0s - 31ms/step - accuracy: 0.3691 - loss: 2.0217 - val_accuracy: 0.2891 - val_loss: 2.0298
# Epoch 27/150
# 16/16 - 0s - 30ms/step - accuracy: 0.3516 - loss: 2.0381 - val_accuracy: 0.3047 - val_loss: 2.0201
# Epoch 28/150
# 16/16 - 0s - 30ms/step - accuracy: 0.3867 - loss: 1.9869 - val_accuracy: 0.3438 - val_loss: 1.9910
# Epoch 29/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4277 - loss: 1.8817 - val_accuracy: 0.3047 - val_loss: 2.0033
# Epoch 30/150
# 16/16 - 0s - 31ms/step - accuracy: 0.3965 - loss: 1.8486 - val_accuracy: 0.2812 - val_loss: 1.9897
# Epoch 31/150
# 16/16 - 0s - 31ms/step - accuracy: 0.3750 - loss: 1.8522 - val_accuracy: 0.2891 - val_loss: 1.9737
# Epoch 32/150
# 16/16 - 0s - 28ms/step - accuracy: 0.3633 - loss: 1.9501 - val_accuracy: 0.3047 - val_loss: 1.9639
# Epoch 33/150
# 16/16 - 0s - 29ms/step - accuracy: 0.4023 - loss: 1.9019 - val_accuracy: 0.3047 - val_loss: 1.9837
# Epoch 34/150
# 16/16 - 0s - 29ms/step - accuracy: 0.3594 - loss: 1.8817 - val_accuracy: 0.2969 - val_loss: 1.9518
# Epoch 35/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4062 - loss: 1.8285 - val_accuracy: 0.2891 - val_loss: 1.9539
# Epoch 36/150
# 16/16 - 0s - 31ms/step - accuracy: 0.3984 - loss: 1.8559 - val_accuracy: 0.2969 - val_loss: 1.9414
# Epoch 37/150
# 16/16 - 1s - 32ms/step - accuracy: 0.3711 - loss: 1.9172 - val_accuracy: 0.2969 - val_loss: 1.9353
# Epoch 38/150
# 16/16 - 1s - 32ms/step - accuracy: 0.4297 - loss: 1.7384 - val_accuracy: 0.3203 - val_loss: 1.9145
# Epoch 39/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4102 - loss: 1.7964 - val_accuracy: 0.3047 - val_loss: 1.9547
# Epoch 40/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4297 - loss: 1.7342 - val_accuracy: 0.3125 - val_loss: 1.9062
# Epoch 41/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4062 - loss: 1.7774 - val_accuracy: 0.3047 - val_loss: 1.9088
# Epoch 42/150
# 16/16 - 0s - 30ms/step - accuracy: 0.3945 - loss: 1.7573 - val_accuracy: 0.3281 - val_loss: 1.8903
# Epoch 43/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4277 - loss: 1.7080 - val_accuracy: 0.3047 - val_loss: 1.9039
# Epoch 44/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4395 - loss: 1.6338 - val_accuracy: 0.3281 - val_loss: 1.8974
# Epoch 45/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4297 - loss: 1.6492 - val_accuracy: 0.3047 - val_loss: 1.8763
# Epoch 46/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4277 - loss: 1.6394 - val_accuracy: 0.2656 - val_loss: 1.9212
# Epoch 47/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4219 - loss: 1.6620 - val_accuracy: 0.2812 - val_loss: 1.8883
# Epoch 48/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4629 - loss: 1.5392 - val_accuracy: 0.2891 - val_loss: 1.8774
# Epoch 49/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4453 - loss: 1.6307 - val_accuracy: 0.2734 - val_loss: 1.9119
# Epoch 50/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4473 - loss: 1.6033 - val_accuracy: 0.3203 - val_loss: 1.8612
# Epoch 51/150
# 16/16 - 1s - 32ms/step - accuracy: 0.4805 - loss: 1.5129 - val_accuracy: 0.3047 - val_loss: 1.8613
# Epoch 52/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4629 - loss: 1.5024 - val_accuracy: 0.3203 - val_loss: 1.8781
# Epoch 53/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4434 - loss: 1.5723 - val_accuracy: 0.3203 - val_loss: 1.8485
# Epoch 54/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4434 - loss: 1.4980 - val_accuracy: 0.2969 - val_loss: 1.8888
# Epoch 55/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4805 - loss: 1.4742 - val_accuracy: 0.3047 - val_loss: 1.8781
# Epoch 56/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4805 - loss: 1.3974 - val_accuracy: 0.3047 - val_loss: 1.8449
# Epoch 57/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4766 - loss: 1.4712 - val_accuracy: 0.2969 - val_loss: 1.8316
# Epoch 58/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5098 - loss: 1.4082 - val_accuracy: 0.3516 - val_loss: 1.8336
# Epoch 59/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4688 - loss: 1.4616 - val_accuracy: 0.3125 - val_loss: 1.8524
# Epoch 60/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5000 - loss: 1.3526 - val_accuracy: 0.3203 - val_loss: 1.8246
# Epoch 61/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5117 - loss: 1.3932 - val_accuracy: 0.3359 - val_loss: 1.8570
# Epoch 62/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5020 - loss: 1.3900 - val_accuracy: 0.3047 - val_loss: 1.8437
# Epoch 63/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4824 - loss: 1.4801 - val_accuracy: 0.3125 - val_loss: 1.8516
# Epoch 64/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4883 - loss: 1.4063 - val_accuracy: 0.2812 - val_loss: 1.8756
# Epoch 65/150
# 16/16 - 1s - 32ms/step - accuracy: 0.4980 - loss: 1.4066 - val_accuracy: 0.2500 - val_loss: 1.8613
# Epoch 66/150
# 16/16 - 1s - 32ms/step - accuracy: 0.4766 - loss: 1.3780 - val_accuracy: 0.3281 - val_loss: 1.8670
# Epoch 67/150
# 16/16 - 1s - 31ms/step - accuracy: 0.4863 - loss: 1.4357 - val_accuracy: 0.2891 - val_loss: 1.8532
# Epoch 68/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5215 - loss: 1.3722 - val_accuracy: 0.2969 - val_loss: 1.8434
# Epoch 69/150
# 16/16 - 0s - 31ms/step - accuracy: 0.4824 - loss: 1.3327 - val_accuracy: 0.3125 - val_loss: 1.8575
# Epoch 70/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5312 - loss: 1.3240 - val_accuracy: 0.3203 - val_loss: 1.8564
# Epoch 71/150
# 16/16 - 1s - 31ms/step - accuracy: 0.5137 - loss: 1.3320 - val_accuracy: 0.3047 - val_loss: 1.8535
# Epoch 72/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5059 - loss: 1.3592 - val_accuracy: 0.3203 - val_loss: 1.8368
# Epoch 73/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5332 - loss: 1.2655 - val_accuracy: 0.3047 - val_loss: 1.8227
# Epoch 74/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5293 - loss: 1.3634 - val_accuracy: 0.3047 - val_loss: 1.8505
# Epoch 75/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5078 - loss: 1.3512 - val_accuracy: 0.2891 - val_loss: 1.8322
# Epoch 76/150
# 16/16 - 1s - 31ms/step - accuracy: 0.5176 - loss: 1.3191 - val_accuracy: 0.3047 - val_loss: 1.8434
# Epoch 77/150
# 16/16 - 1s - 31ms/step - accuracy: 0.5605 - loss: 1.2103 - val_accuracy: 0.3125 - val_loss: 1.8556
# Epoch 78/150
# 16/16 - 0s - 30ms/step - accuracy: 0.4980 - loss: 1.3371 - val_accuracy: 0.3047 - val_loss: 1.8635
# Epoch 79/150
# 16/16 - 0s - 29ms/step - accuracy: 0.4727 - loss: 1.3423 - val_accuracy: 0.3359 - val_loss: 1.8299
# Epoch 80/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5508 - loss: 1.3184 - val_accuracy: 0.3281 - val_loss: 1.8224
# Epoch 81/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5137 - loss: 1.3295 - val_accuracy: 0.2891 - val_loss: 1.8352
# Epoch 82/150
# 16/16 - 1s - 34ms/step - accuracy: 0.5371 - loss: 1.3103 - val_accuracy: 0.3359 - val_loss: 1.8618
# Epoch 83/150
# 16/16 - 1s - 36ms/step - accuracy: 0.5371 - loss: 1.2935 - val_accuracy: 0.3359 - val_loss: 1.8005
# Epoch 84/150
# 16/16 - 1s - 31ms/step - accuracy: 0.5547 - loss: 1.2514 - val_accuracy: 0.3125 - val_loss: 1.8300
# Epoch 85/150
# 16/16 - 1s - 31ms/step - accuracy: 0.5469 - loss: 1.1986 - val_accuracy: 0.3516 - val_loss: 1.8437
# Epoch 86/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5234 - loss: 1.2405 - val_accuracy: 0.3516 - val_loss: 1.8169
# Epoch 87/150
# 16/16 - 1s - 32ms/step - accuracy: 0.5391 - loss: 1.2380 - val_accuracy: 0.2891 - val_loss: 1.8324
# Epoch 88/150
# 16/16 - 1s - 33ms/step - accuracy: 0.5352 - loss: 1.2313 - val_accuracy: 0.3359 - val_loss: 1.8175
# Epoch 89/150
# 16/16 - 1s - 35ms/step - accuracy: 0.4980 - loss: 1.3168 - val_accuracy: 0.3359 - val_loss: 1.8122
# Epoch 90/150
# 16/16 - 1s - 35ms/step - accuracy: 0.5293 - loss: 1.2713 - val_accuracy: 0.3281 - val_loss: 1.8010
# Epoch 91/150
# 16/16 - 1s - 34ms/step - accuracy: 0.5020 - loss: 1.3185 - val_accuracy: 0.3672 - val_loss: 1.7916
# Epoch 92/150
# 16/16 - 1s - 32ms/step - accuracy: 0.5449 - loss: 1.2457 - val_accuracy: 0.3438 - val_loss: 1.8077
# Epoch 93/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5312 - loss: 1.2778 - val_accuracy: 0.3594 - val_loss: 1.7929
# Epoch 94/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5195 - loss: 1.3031 - val_accuracy: 0.3359 - val_loss: 1.8088
# Epoch 95/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5371 - loss: 1.2892 - val_accuracy: 0.3203 - val_loss: 1.8286
# Epoch 96/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5645 - loss: 1.2435 - val_accuracy: 0.3438 - val_loss: 1.8125
# Epoch 97/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5371 - loss: 1.2410 - val_accuracy: 0.3438 - val_loss: 1.8086
# Epoch 98/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5586 - loss: 1.2295 - val_accuracy: 0.3203 - val_loss: 1.8295
# Epoch 99/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5410 - loss: 1.2824 - val_accuracy: 0.3516 - val_loss: 1.8213
# Epoch 100/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5586 - loss: 1.2145 - val_accuracy: 0.2891 - val_loss: 1.8330
# Epoch 101/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5508 - loss: 1.2756 - val_accuracy: 0.3438 - val_loss: 1.7814
# Epoch 102/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5156 - loss: 1.2501 - val_accuracy: 0.2969 - val_loss: 1.8118
# Epoch 103/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5391 - loss: 1.2274 - val_accuracy: 0.3125 - val_loss: 1.8162
# Epoch 104/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5469 - loss: 1.1857 - val_accuracy: 0.3516 - val_loss: 1.8138
# Epoch 105/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5254 - loss: 1.2526 - val_accuracy: 0.3281 - val_loss: 1.8556
# Epoch 106/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5273 - loss: 1.2243 - val_accuracy: 0.3750 - val_loss: 1.8092
# Epoch 107/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5195 - loss: 1.2527 - val_accuracy: 0.3828 - val_loss: 1.8422
# Epoch 108/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5762 - loss: 1.1448 - val_accuracy: 0.3828 - val_loss: 1.8001
# Epoch 109/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5703 - loss: 1.1281 - val_accuracy: 0.3906 - val_loss: 1.8099
# Epoch 110/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5488 - loss: 1.1886 - val_accuracy: 0.3516 - val_loss: 1.8156
# Epoch 111/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5996 - loss: 1.1007 - val_accuracy: 0.3438 - val_loss: 1.8312
# Epoch 112/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5508 - loss: 1.1798 - val_accuracy: 0.3828 - val_loss: 1.8361
# Epoch 113/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5801 - loss: 1.0671 - val_accuracy: 0.3516 - val_loss: 1.8269
# Epoch 114/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5820 - loss: 1.1464 - val_accuracy: 0.3438 - val_loss: 1.8399
# Epoch 115/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5449 - loss: 1.2164 - val_accuracy: 0.3203 - val_loss: 1.8449
# Epoch 116/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5703 - loss: 1.1881 - val_accuracy: 0.3359 - val_loss: 1.8189
# Epoch 117/150
# 16/16 - 1s - 31ms/step - accuracy: 0.5508 - loss: 1.1875 - val_accuracy: 0.3047 - val_loss: 1.9167
# Epoch 118/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5332 - loss: 1.2563 - val_accuracy: 0.3516 - val_loss: 1.8243
# Epoch 119/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5430 - loss: 1.1271 - val_accuracy: 0.3203 - val_loss: 1.8561
# Epoch 120/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5742 - loss: 1.1554 - val_accuracy: 0.3438 - val_loss: 1.8370
# Epoch 121/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5820 - loss: 1.1093 - val_accuracy: 0.3203 - val_loss: 1.8478
# Epoch 122/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5703 - loss: 1.2060 - val_accuracy: 0.3281 - val_loss: 1.8160
# Epoch 123/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5586 - loss: 1.2077 - val_accuracy: 0.3203 - val_loss: 1.8687
# Epoch 124/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5742 - loss: 1.1745 - val_accuracy: 0.3359 - val_loss: 1.8345
# Epoch 125/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5605 - loss: 1.2186 - val_accuracy: 0.3281 - val_loss: 1.8326
# Epoch 126/150
# 16/16 - 1s - 32ms/step - accuracy: 0.5801 - loss: 1.1809 - val_accuracy: 0.2734 - val_loss: 1.8868
# Epoch 127/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5742 - loss: 1.1691 - val_accuracy: 0.3438 - val_loss: 1.8198
# Epoch 128/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5742 - loss: 1.1278 - val_accuracy: 0.2969 - val_loss: 1.8717
# Epoch 129/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5820 - loss: 1.1564 - val_accuracy: 0.3047 - val_loss: 1.8357
# Epoch 130/150
# 16/16 - 0s - 28ms/step - accuracy: 0.5918 - loss: 1.1504 - val_accuracy: 0.3203 - val_loss: 1.8654
# Epoch 131/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5430 - loss: 1.1878 - val_accuracy: 0.2969 - val_loss: 1.8483
# Epoch 132/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5215 - loss: 1.1716 - val_accuracy: 0.3281 - val_loss: 1.8473
# Epoch 133/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5938 - loss: 1.0976 - val_accuracy: 0.3047 - val_loss: 1.8850
# Epoch 134/150
# 16/16 - 0s - 29ms/step - accuracy: 0.6133 - loss: 1.0920 - val_accuracy: 0.2891 - val_loss: 1.8355
# Epoch 135/150
# 16/16 - 0s - 29ms/step - accuracy: 0.5820 - loss: 1.1262 - val_accuracy: 0.3203 - val_loss: 1.8259
# Epoch 136/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5605 - loss: 1.2173 - val_accuracy: 0.3047 - val_loss: 1.8162
# Epoch 137/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5566 - loss: 1.1364 - val_accuracy: 0.2891 - val_loss: 1.8294
# Epoch 138/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5938 - loss: 1.0964 - val_accuracy: 0.3125 - val_loss: 1.8404
# Epoch 139/150
# 16/16 - 1s - 32ms/step - accuracy: 0.5879 - loss: 1.0514 - val_accuracy: 0.3203 - val_loss: 1.8211
# Epoch 140/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5586 - loss: 1.1881 - val_accuracy: 0.2969 - val_loss: 1.8363
# Epoch 141/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5645 - loss: 1.1234 - val_accuracy: 0.3281 - val_loss: 1.8354
# Epoch 142/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5566 - loss: 1.1592 - val_accuracy: 0.3203 - val_loss: 1.8703
# Epoch 143/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5938 - loss: 1.0947 - val_accuracy: 0.3281 - val_loss: 1.8431
# Epoch 144/150
# 16/16 - 0s - 31ms/step - accuracy: 0.6035 - loss: 1.0751 - val_accuracy: 0.3359 - val_loss: 1.8136
# Epoch 145/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5957 - loss: 1.1251 - val_accuracy: 0.3047 - val_loss: 1.8657
# Epoch 146/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5801 - loss: 1.1631 - val_accuracy: 0.3438 - val_loss: 1.8409
# Epoch 147/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5723 - loss: 1.1038 - val_accuracy: 0.3047 - val_loss: 1.8574
# Epoch 148/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5898 - loss: 1.0861 - val_accuracy: 0.3516 - val_loss: 1.8445
# Epoch 149/150
# 16/16 - 0s - 31ms/step - accuracy: 0.5879 - loss: 1.1103 - val_accuracy: 0.3125 - val_loss: 1.8401
# Epoch 150/150
# 16/16 - 0s - 30ms/step - accuracy: 0.5605 - loss: 1.1494 - val_accuracy: 0.3125 - val_loss: 1.8499
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenet_1.00_224 (Functional) │ (None, 3, 3, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │         8,200 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,237,064 (12.35 MB)
#  Trainable params: 8,200 (32.03 KB)
#  Non-trainable params: 3,228,864 (12.32 MB)
# Epoch 150/300
# 16/16 - 2s - 123ms/step - accuracy: 0.5918 - loss: 1.1355 - val_accuracy: 0.3047 - val_loss: 1.8380
# Epoch 151/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5508 - loss: 1.1656 - val_accuracy: 0.3125 - val_loss: 1.8396
# Epoch 152/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5605 - loss: 1.0924 - val_accuracy: 0.3203 - val_loss: 1.8385
# Epoch 153/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5879 - loss: 1.1123 - val_accuracy: 0.3359 - val_loss: 1.8380
# Epoch 154/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5879 - loss: 1.1132 - val_accuracy: 0.3281 - val_loss: 1.8375
# Epoch 155/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5938 - loss: 1.1256 - val_accuracy: 0.3359 - val_loss: 1.8358
# Epoch 156/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5723 - loss: 1.0891 - val_accuracy: 0.3438 - val_loss: 1.8306
# Epoch 157/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5938 - loss: 1.1411 - val_accuracy: 0.3438 - val_loss: 1.8311
# Epoch 158/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6035 - loss: 1.0743 - val_accuracy: 0.3125 - val_loss: 1.8367
# Epoch 159/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5723 - loss: 1.1622 - val_accuracy: 0.3281 - val_loss: 1.8356
# Epoch 160/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5801 - loss: 1.1089 - val_accuracy: 0.3281 - val_loss: 1.8316
# Epoch 161/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6113 - loss: 1.1048 - val_accuracy: 0.3203 - val_loss: 1.8310
# Epoch 162/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5820 - loss: 1.1010 - val_accuracy: 0.3281 - val_loss: 1.8338
# Epoch 163/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6094 - loss: 1.0823 - val_accuracy: 0.3125 - val_loss: 1.8314
# Epoch 164/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6094 - loss: 1.1024 - val_accuracy: 0.3125 - val_loss: 1.8333
# Epoch 165/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5586 - loss: 1.1419 - val_accuracy: 0.3203 - val_loss: 1.8333
# Epoch 166/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5957 - loss: 1.1206 - val_accuracy: 0.3203 - val_loss: 1.8334
# Epoch 167/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6074 - loss: 1.0811 - val_accuracy: 0.3047 - val_loss: 1.8341
# Epoch 168/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5527 - loss: 1.1402 - val_accuracy: 0.3203 - val_loss: 1.8341
# Epoch 169/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5762 - loss: 1.1219 - val_accuracy: 0.3281 - val_loss: 1.8376
# Epoch 170/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5742 - loss: 1.0952 - val_accuracy: 0.3047 - val_loss: 1.8390
# Epoch 171/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5898 - loss: 1.0800 - val_accuracy: 0.3047 - val_loss: 1.8416
# Epoch 172/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6152 - loss: 1.1098 - val_accuracy: 0.2969 - val_loss: 1.8396
# Epoch 173/300
# 16/16 - 0s - 29ms/step - accuracy: 0.5820 - loss: 1.1463 - val_accuracy: 0.3125 - val_loss: 1.8383
# Epoch 174/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6055 - loss: 1.1046 - val_accuracy: 0.3281 - val_loss: 1.8352
# Epoch 175/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6211 - loss: 1.0655 - val_accuracy: 0.3438 - val_loss: 1.8357
# Epoch 176/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6250 - loss: 1.0934 - val_accuracy: 0.3438 - val_loss: 1.8341
# Epoch 177/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5957 - loss: 1.1613 - val_accuracy: 0.3359 - val_loss: 1.8336
# Epoch 178/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6035 - loss: 1.0946 - val_accuracy: 0.3359 - val_loss: 1.8348
# Epoch 179/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6055 - loss: 1.0217 - val_accuracy: 0.3203 - val_loss: 1.8344
# Epoch 180/300
# 16/16 - 0s - 29ms/step - accuracy: 0.5664 - loss: 1.1487 - val_accuracy: 0.3359 - val_loss: 1.8333
# Epoch 181/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5371 - loss: 1.1961 - val_accuracy: 0.3203 - val_loss: 1.8335
# Epoch 182/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5859 - loss: 1.1214 - val_accuracy: 0.3359 - val_loss: 1.8317
# Epoch 183/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5742 - loss: 1.1222 - val_accuracy: 0.3203 - val_loss: 1.8327
# Epoch 184/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6152 - loss: 1.0863 - val_accuracy: 0.3203 - val_loss: 1.8314
# Epoch 185/300
# 16/16 - 1s - 32ms/step - accuracy: 0.6074 - loss: 1.0793 - val_accuracy: 0.3125 - val_loss: 1.8318
# Epoch 186/300
# 16/16 - 1s - 32ms/step - accuracy: 0.5703 - loss: 1.1632 - val_accuracy: 0.3125 - val_loss: 1.8315
# Epoch 187/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6250 - loss: 1.0858 - val_accuracy: 0.3203 - val_loss: 1.8350
# Epoch 188/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6094 - loss: 1.0923 - val_accuracy: 0.3203 - val_loss: 1.8390
# Epoch 189/300
# 16/16 - 1s - 34ms/step - accuracy: 0.6035 - loss: 1.1115 - val_accuracy: 0.3281 - val_loss: 1.8417
# Epoch 190/300
# 16/16 - 1s - 37ms/step - accuracy: 0.5723 - loss: 1.1426 - val_accuracy: 0.3281 - val_loss: 1.8448
# Epoch 191/300
# 16/16 - 1s - 37ms/step - accuracy: 0.6035 - loss: 1.0595 - val_accuracy: 0.3203 - val_loss: 1.8411
# Epoch 192/300
# 16/16 - 1s - 36ms/step - accuracy: 0.5762 - loss: 1.0824 - val_accuracy: 0.3125 - val_loss: 1.8382
# Epoch 193/300
# 16/16 - 1s - 33ms/step - accuracy: 0.6074 - loss: 1.1137 - val_accuracy: 0.3125 - val_loss: 1.8363
# Epoch 194/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5840 - loss: 1.1269 - val_accuracy: 0.3125 - val_loss: 1.8364
# Epoch 195/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5879 - loss: 1.0884 - val_accuracy: 0.3125 - val_loss: 1.8362
# Epoch 196/300
# 16/16 - 1s - 34ms/step - accuracy: 0.5898 - loss: 1.1054 - val_accuracy: 0.3125 - val_loss: 1.8361
# Epoch 197/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5840 - loss: 1.1430 - val_accuracy: 0.3125 - val_loss: 1.8372
# Epoch 198/300
# 16/16 - 0s - 29ms/step - accuracy: 0.5605 - loss: 1.1558 - val_accuracy: 0.3047 - val_loss: 1.8350
# Epoch 199/300
# 16/16 - 0s - 29ms/step - accuracy: 0.6230 - loss: 1.0476 - val_accuracy: 0.3047 - val_loss: 1.8328
# Epoch 200/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5801 - loss: 1.1258 - val_accuracy: 0.3125 - val_loss: 1.8345
# Epoch 201/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6270 - loss: 1.0586 - val_accuracy: 0.3125 - val_loss: 1.8340
# Epoch 202/300
# 16/16 - 0s - 27ms/step - accuracy: 0.5742 - loss: 1.1444 - val_accuracy: 0.3125 - val_loss: 1.8357
# Epoch 203/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6328 - loss: 1.0951 - val_accuracy: 0.3125 - val_loss: 1.8340
# Epoch 204/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5957 - loss: 1.1068 - val_accuracy: 0.3203 - val_loss: 1.8338
# Epoch 205/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6289 - loss: 1.0364 - val_accuracy: 0.3203 - val_loss: 1.8350
# Epoch 206/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6309 - loss: 1.0254 - val_accuracy: 0.3203 - val_loss: 1.8363
# Epoch 207/300
# 16/16 - 0s - 29ms/step - accuracy: 0.5938 - loss: 1.1242 - val_accuracy: 0.3125 - val_loss: 1.8344
# Epoch 208/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5879 - loss: 1.1365 - val_accuracy: 0.3125 - val_loss: 1.8354
# Epoch 209/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5879 - loss: 1.1403 - val_accuracy: 0.3125 - val_loss: 1.8338
# Epoch 210/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5547 - loss: 1.1541 - val_accuracy: 0.3125 - val_loss: 1.8332
# Epoch 211/300
# 16/16 - 1s - 33ms/step - accuracy: 0.5820 - loss: 1.0774 - val_accuracy: 0.3203 - val_loss: 1.8340
# Epoch 212/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5879 - loss: 1.0892 - val_accuracy: 0.3203 - val_loss: 1.8338
# Epoch 213/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6055 - loss: 1.0995 - val_accuracy: 0.3125 - val_loss: 1.8332
# Epoch 214/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5938 - loss: 1.1068 - val_accuracy: 0.3125 - val_loss: 1.8320
# Epoch 215/300
# 16/16 - 1s - 33ms/step - accuracy: 0.5840 - loss: 1.1090 - val_accuracy: 0.3125 - val_loss: 1.8308
# Epoch 216/300
# 16/16 - 1s - 34ms/step - accuracy: 0.5996 - loss: 1.0632 - val_accuracy: 0.3125 - val_loss: 1.8304
# Epoch 217/300
# 16/16 - 1s - 33ms/step - accuracy: 0.6055 - loss: 1.1216 - val_accuracy: 0.3203 - val_loss: 1.8317
# Epoch 218/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5996 - loss: 1.0870 - val_accuracy: 0.3203 - val_loss: 1.8341
# Epoch 219/300
# 16/16 - 1s - 33ms/step - accuracy: 0.5898 - loss: 1.0959 - val_accuracy: 0.3203 - val_loss: 1.8348
# Epoch 220/300
# 16/16 - 1s - 34ms/step - accuracy: 0.5957 - loss: 1.0646 - val_accuracy: 0.3203 - val_loss: 1.8343
# Epoch 221/300
# 16/16 - 1s - 34ms/step - accuracy: 0.6016 - loss: 1.0717 - val_accuracy: 0.3203 - val_loss: 1.8362
# Epoch 222/300
# 16/16 - 1s - 34ms/step - accuracy: 0.5684 - loss: 1.1445 - val_accuracy: 0.3203 - val_loss: 1.8343
# Epoch 223/300
# 16/16 - 1s - 32ms/step - accuracy: 0.5879 - loss: 1.0884 - val_accuracy: 0.3203 - val_loss: 1.8334
# Epoch 224/300
# 16/16 - 1s - 33ms/step - accuracy: 0.5781 - loss: 1.0902 - val_accuracy: 0.3203 - val_loss: 1.8348
# Epoch 225/300
# 16/16 - 1s - 32ms/step - accuracy: 0.6035 - loss: 1.0686 - val_accuracy: 0.3203 - val_loss: 1.8342
# Epoch 226/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5957 - loss: 1.0721 - val_accuracy: 0.3125 - val_loss: 1.8309
# Epoch 227/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5957 - loss: 1.0870 - val_accuracy: 0.3125 - val_loss: 1.8303
# Epoch 228/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6484 - loss: 1.0426 - val_accuracy: 0.3125 - val_loss: 1.8313
# Epoch 229/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5645 - loss: 1.2007 - val_accuracy: 0.3125 - val_loss: 1.8337
# Epoch 230/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5977 - loss: 1.1032 - val_accuracy: 0.3125 - val_loss: 1.8357
# Epoch 231/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6328 - loss: 1.0398 - val_accuracy: 0.3203 - val_loss: 1.8360
# Epoch 232/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5977 - loss: 1.1258 - val_accuracy: 0.3203 - val_loss: 1.8353
# Epoch 233/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6016 - loss: 1.0562 - val_accuracy: 0.3281 - val_loss: 1.8357
# Epoch 234/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6016 - loss: 1.0777 - val_accuracy: 0.3359 - val_loss: 1.8351
# Epoch 235/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5879 - loss: 1.1061 - val_accuracy: 0.3281 - val_loss: 1.8354
# Epoch 236/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5938 - loss: 1.1107 - val_accuracy: 0.3203 - val_loss: 1.8358
# Epoch 237/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6152 - loss: 1.0691 - val_accuracy: 0.3203 - val_loss: 1.8372
# Epoch 238/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5996 - loss: 1.0717 - val_accuracy: 0.3125 - val_loss: 1.8370
# Epoch 239/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5918 - loss: 1.1267 - val_accuracy: 0.3125 - val_loss: 1.8365
# Epoch 240/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6191 - loss: 1.0482 - val_accuracy: 0.3125 - val_loss: 1.8365
# Epoch 241/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5957 - loss: 1.0910 - val_accuracy: 0.3203 - val_loss: 1.8368
# Epoch 242/300
# 16/16 - 1s - 32ms/step - accuracy: 0.6055 - loss: 1.0605 - val_accuracy: 0.3203 - val_loss: 1.8370
# Epoch 243/300
# 16/16 - 1s - 32ms/step - accuracy: 0.5977 - loss: 1.1590 - val_accuracy: 0.3203 - val_loss: 1.8380
# Epoch 244/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5840 - loss: 1.1700 - val_accuracy: 0.3203 - val_loss: 1.8380
# Epoch 245/300
# 16/16 - 1s - 32ms/step - accuracy: 0.6016 - loss: 1.0524 - val_accuracy: 0.3203 - val_loss: 1.8379
# Epoch 246/300
# 16/16 - 1s - 32ms/step - accuracy: 0.5859 - loss: 1.1103 - val_accuracy: 0.3203 - val_loss: 1.8371
# Epoch 247/300
# 16/16 - 1s - 32ms/step - accuracy: 0.5938 - loss: 1.1043 - val_accuracy: 0.3203 - val_loss: 1.8374
# Epoch 248/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5898 - loss: 1.1093 - val_accuracy: 0.3203 - val_loss: 1.8372
# Epoch 249/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5508 - loss: 1.1741 - val_accuracy: 0.3125 - val_loss: 1.8368
# Epoch 250/300
# 16/16 - 1s - 34ms/step - accuracy: 0.5879 - loss: 1.1094 - val_accuracy: 0.3125 - val_loss: 1.8365
# Epoch 251/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5605 - loss: 1.1168 - val_accuracy: 0.3203 - val_loss: 1.8369
# Epoch 252/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5977 - loss: 1.0736 - val_accuracy: 0.3203 - val_loss: 1.8368
# Epoch 253/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5996 - loss: 1.0972 - val_accuracy: 0.3203 - val_loss: 1.8368
# Epoch 254/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5703 - loss: 1.1340 - val_accuracy: 0.3203 - val_loss: 1.8379
# Epoch 255/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6094 - loss: 1.0276 - val_accuracy: 0.3125 - val_loss: 1.8383
# Epoch 256/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5938 - loss: 1.0895 - val_accuracy: 0.3125 - val_loss: 1.8369
# Epoch 257/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6094 - loss: 1.0807 - val_accuracy: 0.3203 - val_loss: 1.8349
# Epoch 258/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5801 - loss: 1.1395 - val_accuracy: 0.3203 - val_loss: 1.8350
# Epoch 259/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5879 - loss: 1.1361 - val_accuracy: 0.3203 - val_loss: 1.8351
# Epoch 260/300
# 16/16 - 0s - 29ms/step - accuracy: 0.6152 - loss: 1.0931 - val_accuracy: 0.3125 - val_loss: 1.8366
# Epoch 261/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6016 - loss: 1.0617 - val_accuracy: 0.3281 - val_loss: 1.8365
# Epoch 262/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5566 - loss: 1.1558 - val_accuracy: 0.3203 - val_loss: 1.8360
# Epoch 263/300
# 16/16 - 1s - 32ms/step - accuracy: 0.5879 - loss: 1.1646 - val_accuracy: 0.3125 - val_loss: 1.8374
# Epoch 264/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5879 - loss: 1.0878 - val_accuracy: 0.3125 - val_loss: 1.8378
# Epoch 265/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5840 - loss: 1.1438 - val_accuracy: 0.3125 - val_loss: 1.8376
# Epoch 266/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6094 - loss: 1.1006 - val_accuracy: 0.3125 - val_loss: 1.8379
# Epoch 267/300
# 16/16 - 1s - 31ms/step - accuracy: 0.6074 - loss: 1.0811 - val_accuracy: 0.3125 - val_loss: 1.8378
# Epoch 268/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5977 - loss: 1.1170 - val_accuracy: 0.3125 - val_loss: 1.8390
# Epoch 269/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5703 - loss: 1.1073 - val_accuracy: 0.3125 - val_loss: 1.8370
# Epoch 270/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5918 - loss: 1.0801 - val_accuracy: 0.3203 - val_loss: 1.8357
# Epoch 271/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6016 - loss: 1.0297 - val_accuracy: 0.3125 - val_loss: 1.8358
# Epoch 272/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5781 - loss: 1.1236 - val_accuracy: 0.3203 - val_loss: 1.8363
# Epoch 273/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5801 - loss: 1.1627 - val_accuracy: 0.3203 - val_loss: 1.8372
# Epoch 274/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5938 - loss: 1.0765 - val_accuracy: 0.3125 - val_loss: 1.8374
# Epoch 275/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6250 - loss: 1.0801 - val_accuracy: 0.3125 - val_loss: 1.8364
# Epoch 276/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6172 - loss: 1.0171 - val_accuracy: 0.3125 - val_loss: 1.8371
# Epoch 277/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6016 - loss: 1.1374 - val_accuracy: 0.3125 - val_loss: 1.8373
# Epoch 278/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6035 - loss: 1.0809 - val_accuracy: 0.3125 - val_loss: 1.8378
# Epoch 279/300
# 16/16 - 1s - 32ms/step - accuracy: 0.5918 - loss: 1.1065 - val_accuracy: 0.3125 - val_loss: 1.8369
# Epoch 280/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5996 - loss: 1.1033 - val_accuracy: 0.3125 - val_loss: 1.8372
# Epoch 281/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5977 - loss: 1.0760 - val_accuracy: 0.3125 - val_loss: 1.8373
# Epoch 282/300
# 16/16 - 1s - 31ms/step - accuracy: 0.6113 - loss: 1.1049 - val_accuracy: 0.3125 - val_loss: 1.8365
# Epoch 283/300
# 16/16 - 1s - 31ms/step - accuracy: 0.5879 - loss: 1.0924 - val_accuracy: 0.3125 - val_loss: 1.8366
# Epoch 284/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5605 - loss: 1.1209 - val_accuracy: 0.3125 - val_loss: 1.8363
# Epoch 285/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5996 - loss: 1.0892 - val_accuracy: 0.3125 - val_loss: 1.8353
# Epoch 286/300
# 16/16 - 0s - 29ms/step - accuracy: 0.6133 - loss: 1.0155 - val_accuracy: 0.3125 - val_loss: 1.8355
# Epoch 287/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6211 - loss: 1.0596 - val_accuracy: 0.3125 - val_loss: 1.8353
# Epoch 288/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5723 - loss: 1.1401 - val_accuracy: 0.3203 - val_loss: 1.8354
# Epoch 289/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5977 - loss: 1.0848 - val_accuracy: 0.3203 - val_loss: 1.8355
# Epoch 290/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5996 - loss: 1.0996 - val_accuracy: 0.3281 - val_loss: 1.8351
# Epoch 291/300
# 16/16 - 0s - 30ms/step - accuracy: 0.5781 - loss: 1.1803 - val_accuracy: 0.3281 - val_loss: 1.8348
# Epoch 292/300
# 16/16 - 0s - 29ms/step - accuracy: 0.5859 - loss: 1.1392 - val_accuracy: 0.3203 - val_loss: 1.8354
# Epoch 293/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5723 - loss: 1.1194 - val_accuracy: 0.3203 - val_loss: 1.8357
# Epoch 294/300
# 16/16 - 0s - 28ms/step - accuracy: 0.6211 - loss: 1.0251 - val_accuracy: 0.3203 - val_loss: 1.8357
# Epoch 295/300
# 16/16 - 0s - 31ms/step - accuracy: 0.6172 - loss: 1.1094 - val_accuracy: 0.3203 - val_loss: 1.8352
# Epoch 296/300
# 16/16 - 0s - 29ms/step - accuracy: 0.5879 - loss: 1.1258 - val_accuracy: 0.3203 - val_loss: 1.8357
# Epoch 297/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5762 - loss: 1.1222 - val_accuracy: 0.3125 - val_loss: 1.8351
# Epoch 298/300
# 16/16 - 0s - 28ms/step - accuracy: 0.5742 - loss: 1.1034 - val_accuracy: 0.3125 - val_loss: 1.8348
# Epoch 299/300
# 16/16 - 0s - 30ms/step - accuracy: 0.6445 - loss: 1.0252 - val_accuracy: 0.3125 - val_loss: 1.8337
# Epoch 300/300
# 16/16 - 0s - 31ms/step - accuracy: 0.5879 - loss: 1.1218 - val_accuracy: 0.3125 - val_loss: 1.8330

# %%
def plot_performance(history, learning_rate=None, batch_size=None, finetune_epochs=None):
  plt.figure(figsize=(10,5))

  

  # Determine whether history is keras history or a dictionary to appropriately extract the history data
  if isinstance(history, keras.src.callbacks.history.History):
    history_data = history.history        # Extract the history dictionary
  else:
    history_data = history                # Assume it's already a dictionary

  # Accuracy of model training and validation vs training epoch
  plt.subplot(1,2,1)
  ylim_acc = [0, max(max(history_data['accuracy']),max(history_data['val_accuracy']))]
  plt.plot(history_data['accuracy'], label = 'Training accuracy')
  plt.plot(history_data['val_accuracy'], label = 'Validation accuracy')
  plt.ylim(ylim_acc)
  if finetune_epochs:
    plt.plot([finetune_epochs-1, finetune_epochs-1],plt.ylim(), label = 'Fine tuning')
  else:
    pass

  if learning_rate and batch_size:
    plt.title(f'Model accuracy \n lr = {learning_rate}, batch size = {batch_size}')
  else: plt.title('Model accuracy')

  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(loc='lower right')

  # Loss during model training and validation
  plt.subplot(1,2,2)
  ylim_loss = [0, max(max(history_data['loss']),max(history_data['val_loss']))]
  # print(len(history_data['loss']))
  plt.plot(history_data['loss'], label = 'Training loss')
  plt.plot(history_data['val_loss'], label = 'Validation loss')
  plt.ylim(ylim_loss)
  if finetune_epochs:
    plt.plot([finetune_epochs-1, finetune_epochs-1],plt.ylim(), label = 'Fine tuning')
  else:
    pass

  if learning_rate and batch_size:
    plt.title(f'Model loss \n lr = {learning_rate}, batch size = {batch_size}')
  else: plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(loc='lower right')
  plt.show()

  print(f"The model has a training accuracy of {history_data['accuracy'][-1]*100:.2f}%\n"
      f"The model has a validation accuracy of {history_data['val_accuracy'][-1]*100:.2f}%")
  return

# %%
combined_history = {
    'accuracy': history_initial.history['accuracy'] + history_fine.history['accuracy'],
    'val_accuracy': history_initial.history['val_accuracy'] + history_fine.history['val_accuracy'],
    'loss': history_initial.history['loss'] + history_fine.history['loss'],
    'val_loss': history_initial.history['val_loss'] + history_fine.history['val_loss']
}

plot_performance(combined_history,finetune_epochs=initial_epochs)
# Out:
# The model has a training accuracy of 58.79%
# The model has a validation accuracy of 31.25%

# %% [markdown]
# ## Model evaluation and prediction

# %% [markdown]
# ### Model evaluation

# %%
test_loss, test_acc =  model.evaluate(image_test_array,label_test_array)
print(f"Test accuracy: {test_acc}\n"
      f"Test loss: {test_loss}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3009 - loss: 1.9875
# Test accuracy: 0.3062500059604645
# Test loss: 1.9206565618515015

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

prediction_array = np.argmax(model.predict(image_test_array), axis=1)

cm = confusion_matrix(label_test_array, prediction_array)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)  # You can change the color map as desired
plt.title("Confusion Matrix")
plt.show()
print(label_dict)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# {0: 'anger', 1: 'contempt', 2: 'disgust', 3: 'fear', 4: 'happy', 5: 'neutral', 6: 'sad', 7: 'suprise'}

# %% [markdown]
# ### Model prediction & visualization

# %%
# Sample random images and their indices
num_samples = 25                                                                             # number of samples to be display
num_rows = int(round(sqrt(num_samples))); num_cols = int(num_samples/num_rows)      # number of rows and columns for the subplot
rand = random.randint(num_test,size = (num_samples))                                       # random index for choosing the samples in the dataset

image_test_rand_array = image_test_array[rand]
label_test_rand_array = label_test_array[rand]
prediction_rand_array = np.argmax(model.predict(image_test_rand_array),axis=1)

plt.figure(figsize=(num_rows*2,num_cols*2))
# fig, axes1 = plt.subplots(num_rows,num_cols,figsize=(num_rows*2,num_cols*2))

for i in range(num_rows):
    for j in range(num_cols):
        index = i * num_cols + j
        plt.subplot(num_rows,num_cols,index+1)
        image = image_test_rand_array[index]  # Extract the image
        label = label_test_rand_array[index]  # Extract the label
        prediction = prediction_rand_array[index]

        # Original pictures (no augmentation layer applied)
        plt.axis("off")
        # Display the image
        plt.imshow(image)
        plt.title(f"Label: {label_dict[label]}\n"
                  f"Predict: {label_dict[prediction]}",
                  fontsize = 8) 

plt.tight_layout()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
